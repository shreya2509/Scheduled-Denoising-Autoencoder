# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya2509/Scheduled-Denoising-Autoencoder/blob/master/Denoise_ScheDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.models import load_model
from keras.datasets import cifar10
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation, Flatten, Reshape
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras.layers.advanced_activations import ELU
import os
import pickle
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_noise = np.copy(x_train)
x_test_noise = np.copy(x_test)
x_train_noise=x_train_noise.astype('float32')
x_test_noise=x_test_noise.astype('float32')
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
def normalize(img):
  img =img/255
  return img

# %%
# Function to add masking noise

def addnoise(img,p):
  img=normalize(img)
  for i in range(0,img.shape[0]):
    for j in range(0,img.shape[1]):
      e=np.random.random()
      if (e<p):
        img[i,j,:]=0
  return img

# %%
for i in range(0,len(x_train_noise)):
  x_train_noise[i]=addnoise(x_train_noise[i],0.2)

# %%
for i in range(0,len(x_test_noise)):
  x_test_noise[i]=addnoise(x_test_noise[i],0.2)

# %%
for i in range(0,len(x_train)):
  x_train[i]=normalize(x_train[i])

# %%
for i in range(0,len(x_test)):
  x_test[i]=normalize(x_test[i])

# %%
# Function to visualize the noise added

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(20, 4))
for i in range(0,10):
  ax=plt.subplot(2,10,i+1)
  plt.imshow(x_train_noise[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
for i in range(0,10):
  ax=plt.subplot(2,10,i+11)
  plt.imshow(x_train[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %% [markdown]
# Convolutional Autoencoder

# %%
input_img = Input(shape=(32, 32, 3))
x = Conv2D(32, (3, 3), padding='same')(input_img)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Flatten()(x)
x = Dense(3072)(x)
x = BatchNormalization()(x)
encoded = Activation('sigmoid')(x)

# %%
x = Dense(3072)(encoded)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Reshape((32,32,3))(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(3, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
decoded = Activation('sigmoid')(x)

# %%
model = Model(input_img, decoded)
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
checkpoint_path = "checkpoints"
es_cb = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
chkpt = checkpoint_path + 'AutoEncoder_Cifar10_delineBlack_CAE_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

# %%
cp_callback =ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %% [markdown]
# Training the Autoencoder

# %%
history = model.fit(x_train_noise, x_train,
                    batch_size=50,
                    epochs=100,
                    verbose=1,
                    validation_data=(x_test_noise, x_test),
                    callbacks=[cp_cb,es_cb],
                    shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 178s 4ms/step - loss: 0.0088 - val_loss: 0.0040
#
# Epoch 00001: val_loss improved from inf to 0.00395, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.01-0.01-0.00.hdf5
# Epoch 2/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0044 - val_loss: 0.0035
#
# Epoch 00002: val_loss improved from 0.00395 to 0.00350, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.02-0.00-0.00.hdf5
# Epoch 3/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0036 - val_loss: 0.0024
#
# Epoch 00003: val_loss improved from 0.00350 to 0.00235, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.03-0.00-0.00.hdf5
# Epoch 4/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0032 - val_loss: 0.0022
#
# Epoch 00004: val_loss improved from 0.00235 to 0.00217, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.04-0.00-0.00.hdf5
# Epoch 5/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0029 - val_loss: 0.0021
#
# Epoch 00005: val_loss improved from 0.00217 to 0.00213, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.05-0.00-0.00.hdf5
# Epoch 6/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0027 - val_loss: 0.0022
#
# Epoch 00006: val_loss did not improve from 0.00213
# Epoch 7/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0025 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00213 to 0.00182, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.07-0.00-0.00.hdf5
# Epoch 8/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0024 - val_loss: 0.0020
#
# Epoch 00008: val_loss did not improve from 0.00182
# Epoch 9/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0023 - val_loss: 0.0016
#
# Epoch 00009: val_loss improved from 0.00182 to 0.00155, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.09-0.00-0.00.hdf5
# Epoch 10/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0022 - val_loss: 0.0018
#
# Epoch 00010: val_loss did not improve from 0.00155
# Epoch 11/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0021 - val_loss: 0.0019
#
# Epoch 00011: val_loss did not improve from 0.00155
# Epoch 12/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0020 - val_loss: 0.0014
#
# Epoch 00012: val_loss improved from 0.00155 to 0.00143, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.12-0.00-0.00.hdf5
# Epoch 13/100
# 50000/50000 [==============================] - 174s 3ms/step - loss: 0.0019 - val_loss: 0.0016
#
# Epoch 00013: val_loss did not improve from 0.00143
# Epoch 14/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0019 - val_loss: 0.0013
#
# Epoch 00014: val_loss improved from 0.00143 to 0.00134, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.14-0.00-0.00.hdf5
# Epoch 15/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0018 - val_loss: 0.0014
#
# Epoch 00015: val_loss did not improve from 0.00134
# Epoch 16/100
# 50000/50000 [==============================] - 170s 3ms/step - loss: 0.0018 - val_loss: 0.0013
#
# Epoch 00016: val_loss improved from 0.00134 to 0.00131, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.16-0.00-0.00.hdf5
# Epoch 17/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0017 - val_loss: 0.0013
#
# Epoch 00017: val_loss improved from 0.00131 to 0.00129, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.17-0.00-0.00.hdf5
# Epoch 18/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0017 - val_loss: 0.0013
#
# Epoch 00018: val_loss improved from 0.00129 to 0.00127, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.18-0.00-0.00.hdf5
# Epoch 19/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0016 - val_loss: 0.0015
#
# Epoch 00019: val_loss did not improve from 0.00127
# Epoch 20/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0016 - val_loss: 0.0015
#
# Epoch 00020: val_loss did not improve from 0.00127
# Epoch 21/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0016 - val_loss: 0.0012
#
# Epoch 00021: val_loss improved from 0.00127 to 0.00117, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.21-0.00-0.00.hdf5
# Epoch 22/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0015 - val_loss: 0.0012
#
# Epoch 00022: val_loss did not improve from 0.00117
# Epoch 23/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0015 - val_loss: 0.0011
#
# Epoch 00023: val_loss improved from 0.00117 to 0.00115, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.23-0.00-0.00.hdf5
# Epoch 24/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0015 - val_loss: 0.0012
#
# Epoch 00024: val_loss did not improve from 0.00115
# Epoch 25/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0014 - val_loss: 0.0014
#
# Epoch 00025: val_loss did not improve from 0.00115
# Epoch 26/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00026: val_loss improved from 0.00115 to 0.00109, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.26-0.00-0.00.hdf5
# Epoch 27/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00027: val_loss improved from 0.00109 to 0.00109, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.27-0.00-0.00.hdf5
# Epoch 28/100
# 50000/50000 [==============================] - 170s 3ms/step - loss: 0.0014 - val_loss: 0.0013
#
# Epoch 00028: val_loss did not improve from 0.00109
# Epoch 29/100
# 50000/50000 [==============================] - 170s 3ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00029: val_loss did not improve from 0.00109
# Epoch 30/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00030: val_loss improved from 0.00109 to 0.00107, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.30-0.00-0.00.hdf5
# Epoch 31/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00031: val_loss did not improve from 0.00107
# Epoch 32/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00032: val_loss improved from 0.00107 to 0.00105, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.32-0.00-0.00.hdf5
# Epoch 33/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00033: val_loss did not improve from 0.00105
# Epoch 34/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0012 - val_loss: 0.0015
#
# Epoch 00034: val_loss did not improve from 0.00105
# Epoch 35/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0012 - val_loss: 0.0012
#
# Epoch 00035: val_loss did not improve from 0.00105
# Epoch 36/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00036: val_loss did not improve from 0.00105
# Epoch 37/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00037: val_loss did not improve from 0.00105
# Epoch 38/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0012 - val_loss: 0.0012
#
# Epoch 00038: val_loss did not improve from 0.00105
# Epoch 39/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00039: val_loss did not improve from 0.00105
# Epoch 40/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0012 - val_loss: 0.0010
#
# Epoch 00040: val_loss improved from 0.00105 to 0.00103, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.40-0.00-0.00.hdf5
# Epoch 41/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00041: val_loss did not improve from 0.00103
# Epoch 42/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0011 - val_loss: 0.0012
#
# Epoch 00042: val_loss did not improve from 0.00103
# Epoch 43/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00043: val_loss did not improve from 0.00103
# Epoch 44/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00044: val_loss did not improve from 0.00103
# Epoch 45/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0011 - val_loss: 0.0012
#
# Epoch 00045: val_loss did not improve from 0.00103
# Epoch 46/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00046: val_loss did not improve from 0.00103
# Epoch 47/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00047: val_loss did not improve from 0.00103
# Epoch 48/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00048: val_loss did not improve from 0.00103
# Epoch 49/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0011 - val_loss: 0.0010
#
# Epoch 00049: val_loss improved from 0.00103 to 0.00103, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.49-0.00-0.00.hdf5
# Epoch 50/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00050: val_loss did not improve from 0.00103
# Epoch 51/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0011 - val_loss: 0.0012
#
# Epoch 00051: val_loss did not improve from 0.00103
# Epoch 52/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0010 - val_loss: 0.0010
#
# Epoch 00052: val_loss improved from 0.00103 to 0.00102, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.52-0.00-0.00.hdf5
# Epoch 53/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0011 - val_loss: 0.0010
#
# Epoch 00053: val_loss did not improve from 0.00102
# Epoch 54/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0010 - val_loss: 0.0011
#
# Epoch 00054: val_loss did not improve from 0.00102
# Epoch 55/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0010 - val_loss: 0.0011
#
# Epoch 00055: val_loss did not improve from 0.00102
# Epoch 56/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0010 - val_loss: 0.0011
#
# Epoch 00056: val_loss did not improve from 0.00102
# Epoch 57/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.0010 - val_loss: 0.0010
#
# Epoch 00057: val_loss improved from 0.00102 to 0.00101, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.57-0.00-0.00.hdf5
# Epoch 58/100
# 50000/50000 [==============================] - 174s 3ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00058: val_loss did not improve from 0.00101
# Epoch 59/100
# 50000/50000 [==============================] - 175s 3ms/step - loss: 0.0010 - val_loss: 0.0011
#
# Epoch 00059: val_loss did not improve from 0.00101
# Epoch 60/100
# 50000/50000 [==============================] - 173s 3ms/step - loss: 0.0010 - val_loss: 9.9640e-04
#
# Epoch 00060: val_loss improved from 0.00101 to 0.00100, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.60-0.00-0.00.hdf5
# Epoch 61/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 9.9857e-04 - val_loss: 0.0011
#
# Epoch 00061: val_loss did not improve from 0.00100
# Epoch 62/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00062: val_loss did not improve from 0.00100
# Epoch 63/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 9.7901e-04 - val_loss: 0.0010
#
# Epoch 00063: val_loss did not improve from 0.00100
# Epoch 64/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 9.9292e-04 - val_loss: 0.0010
#
# Epoch 00064: val_loss did not improve from 0.00100
# Epoch 65/100
# 50000/50000 [==============================] - 171s 3ms/step - loss: 9.6671e-04 - val_loss: 9.4843e-04
#
# Epoch 00065: val_loss improved from 0.00100 to 0.00095, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.65-0.00-0.00.hdf5
# Epoch 66/100
# 50000/50000 [==============================] - 179s 4ms/step - loss: 9.6450e-04 - val_loss: 9.9065e-04
#
# Epoch 00066: val_loss did not improve from 0.00095
# Epoch 67/100
# 50000/50000 [==============================] - 178s 4ms/step - loss: 9.5407e-04 - val_loss: 9.9136e-04
#
# Epoch 00067: val_loss did not improve from 0.00095
# Epoch 68/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 9.6308e-04 - val_loss: 0.0010
#
# Epoch 00068: val_loss did not improve from 0.00095
# Epoch 69/100
# 50000/50000 [==============================] - 173s 3ms/step - loss: 9.5982e-04 - val_loss: 0.0012
#
# Epoch 00069: val_loss did not improve from 0.00095
# Epoch 70/100
# 50000/50000 [==============================] - 173s 3ms/step - loss: 9.4621e-04 - val_loss: 0.0010
#
# Epoch 00070: val_loss did not improve from 0.00095
# Epoch 71/100
# 50000/50000 [==============================] - 173s 3ms/step - loss: 9.5844e-04 - val_loss: 0.0011
#
# Epoch 00071: val_loss did not improve from 0.00095
# Epoch 72/100
# 50000/50000 [==============================] - 173s 3ms/step - loss: 9.3542e-04 - val_loss: 9.8753e-04
#
# Epoch 00072: val_loss did not improve from 0.00095
# Epoch 73/100
# 50000/50000 [==============================] - 174s 3ms/step - loss: 9.3700e-04 - val_loss: 0.0010
#
# Epoch 00073: val_loss did not improve from 0.00095
# Epoch 74/100
# 50000/50000 [==============================] - 173s 3ms/step - loss: 9.3599e-04 - val_loss: 9.6928e-04
#
# Epoch 00074: val_loss did not improve from 0.00095
# Epoch 75/100
# 50000/50000 [==============================] - 173s 3ms/step - loss: 9.2504e-04 - val_loss: 0.0011
#
# Epoch 00075: val_loss did not improve from 0.00095
# Epoch 00075: early stopping

# %%
c10test = model.predict(x_test_noise)

# %%
plt.figure(figsize=(20, 6))
for i in range(0,10):
  ax=plt.subplot(3,10,i+1)
  plt.imshow(x_test_noise[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
#for i in range(0,10):
#  ax=plt.subplot(2,10,i+11)
#  plt.imshow(x_train[i])
#  ax.get_xaxis().set_visible(False)
#  ax.get_yaxis().set_visible(False)
for i in range(0,10):
  ax=plt.subplot(3,10,i+11)
  plt.imshow(c10test[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

for i in range(0,10):
  ax=plt.subplot(3,10,i+21)
  plt.imshow(x_test[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
