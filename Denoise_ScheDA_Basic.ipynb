# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya2509/Denoising-Autoencoder/blob/master/Denoise_ScheDA_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.models import load_model
from keras.datasets import cifar10
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation, Flatten, Reshape
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras.layers.advanced_activations import ELU
import os
import pickle
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_noise = np.copy(x_train)
x_test_noise = np.copy(x_test)
x_train_noise=x_train_noise.astype('float32')
x_test_noise=x_test_noise.astype('float32')
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

# %%
def normalize(img):
  img =img/255
  return img

# %%
# Function to add masking noise

def addnoise(img,p):
  img=normalize(img)
  for i in range(0,img.shape[0]):
    for j in range(0,img.shape[1]):
      e=np.random.random()
      if (e<p):
        img[i,j,:]=0
  return img

# %%
for i in range(0,len(x_train_noise)):
  x_train_noise[i]=addnoise(x_train_noise[i],0.2)

# %%
for i in range(0,len(x_test_noise)):
  x_test_noise[i]=addnoise(x_test_noise[i],0.2)

# %%
for i in range(0,len(x_train)):
  x_train[i]=normalize(x_train[i])

# %%
for i in range(0,len(x_test)):
  x_test[i]=normalize(x_test[i])

# %%
# Function to visualize the noise added

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(20, 4))
for i in range(0,10):
  ax=plt.subplot(2,10,i+1)
  plt.imshow(x_train_noise[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
for i in range(0,10):
  ax=plt.subplot(2,10,i+11)
  plt.imshow(x_train[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %% [markdown]
# Convolutional Autoencoder

# %%
input_img = Input(shape=(32, 32, 3))
x = Conv2D(32, (3, 3), padding='same')(input_img)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Flatten()(x)
x = Dense(3072)(x)
x = BatchNormalization()(x)
encoded = Activation('sigmoid')(x)

# %%
x = Dense(3072)(encoded)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Reshape((32,32,3))(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
x = Conv2D(3, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
decoded = Activation('sigmoid')(x)

# %%
model = Model(input_img, decoded)
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
checkpoint_path = "checkpoints"
es_cb = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
chkpt = checkpoint_path + 'AutoEncoder_Cifar10_delineBlack_CAE_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

# %%
cp_callback =ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %% [markdown]
# Training the Autoencoder

# %%
history = model.fit(x_train_noise, x_train,
                    batch_size=50,
                    epochs=100,
                    verbose=1,
                    validation_data=(x_test_noise, x_test),
                    callbacks=[cp_cb,es_cb],
                    shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 60s 1ms/step - loss: 0.0089 - val_loss: 0.0042
#
# Epoch 00001: val_loss improved from inf to 0.00415, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.01-0.01-0.00.hdf5
# Epoch 2/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0044 - val_loss: 0.0041
#
# Epoch 00002: val_loss improved from 0.00415 to 0.00411, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.02-0.00-0.00.hdf5
# Epoch 3/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0036 - val_loss: 0.0025
#
# Epoch 00003: val_loss improved from 0.00411 to 0.00246, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.03-0.00-0.00.hdf5
# Epoch 4/100
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.0032 - val_loss: 0.0030
#
# Epoch 00004: val_loss did not improve from 0.00246
# Epoch 5/100
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.0029 - val_loss: 0.0021
#
# Epoch 00005: val_loss improved from 0.00246 to 0.00206, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.05-0.00-0.00.hdf5
# Epoch 6/100
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.0026 - val_loss: 0.0021
#
# Epoch 00006: val_loss did not improve from 0.00206
# Epoch 7/100
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.0025 - val_loss: 0.0019
#
# Epoch 00007: val_loss improved from 0.00206 to 0.00195, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.07-0.00-0.00.hdf5
# Epoch 8/100
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.0024 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00195 to 0.00165, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.08-0.00-0.00.hdf5
# Epoch 9/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0022 - val_loss: 0.0016
#
# Epoch 00009: val_loss improved from 0.00165 to 0.00162, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.09-0.00-0.00.hdf5
# Epoch 10/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0022 - val_loss: 0.0016
#
# Epoch 00010: val_loss did not improve from 0.00162
# Epoch 11/100
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.0021 - val_loss: 0.0014
#
# Epoch 00011: val_loss improved from 0.00162 to 0.00144, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.11-0.00-0.00.hdf5
# Epoch 12/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0020 - val_loss: 0.0014
#
# Epoch 00012: val_loss improved from 0.00144 to 0.00141, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.12-0.00-0.00.hdf5
# Epoch 13/100
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.0020 - val_loss: 0.0017
#
# Epoch 00013: val_loss did not improve from 0.00141
# Epoch 14/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0019 - val_loss: 0.0015
#
# Epoch 00014: val_loss did not improve from 0.00141
# Epoch 15/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0018 - val_loss: 0.0014
#
# Epoch 00015: val_loss improved from 0.00141 to 0.00138, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.15-0.00-0.00.hdf5
# Epoch 16/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0018 - val_loss: 0.0015
#
# Epoch 00016: val_loss did not improve from 0.00138
# Epoch 17/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0017 - val_loss: 0.0013
#
# Epoch 00017: val_loss improved from 0.00138 to 0.00130, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.17-0.00-0.00.hdf5
# Epoch 18/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0017 - val_loss: 0.0012
#
# Epoch 00018: val_loss improved from 0.00130 to 0.00125, saving model to checkpointsAutoEncoder_Cifar10_delineBlack_CAE_weights.18-0.00-0.00.hdf5
# Epoch 19/100
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.0017 - val_loss: 0.0015
#
# Epoch 00019: val_loss did not improve from 0.00125
# Epoch 20/100
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.0017 - val_loss: 0.0016
#
# Epoch 00020: val_loss did not improve from 0.00125
# Epoch 21/100
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.0016 - val_loss: 0.0013
#
# Epoch 00021: val_loss did not improve from 0.00125
# Epoch 00021: early stopping

# %%
c10test = model.predict(x_test_noise)

# %%
plt.figure(figsize=(20, 6))
for i in range(0,10):
  ax=plt.subplot(3,10,i+1)
  plt.imshow(x_test_noise[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
#for i in range(0,10):
#  ax=plt.subplot(2,10,i+11)
#  plt.imshow(x_train[i])
#  ax.get_xaxis().set_visible(False)
#  ax.get_yaxis().set_visible(False)
for i in range(0,10):
  ax=plt.subplot(3,10,i+11)
  plt.imshow(c10test[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

for i in range(0,10):
  ax=plt.subplot(3,10,i+21)
  plt.imshow(x_test[i])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
